# %%
# !pip3 install torch torchvision torchaudio
# Out:
# Collecting torch
#   Downloading torch-2.0.0-cp311-none-macosx_10_9_x86_64.whl (139.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.5/139.5 MB 11.3 MB/s eta 0:00:0000:0100:01
# Collecting torchvision
#   Downloading torchvision-0.15.1-cp311-cp311-macosx_10_9_x86_64.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 15.3 MB/s eta 0:00:0000:0100:01
# Collecting torchaudio
#   Downloading torchaudio-2.0.1-cp311-cp311-macosx_10_9_x86_64.whl (3.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 15.5 MB/s eta 0:00:0000:0100:01
# Collecting filelock (from torch)
#   Using cached filelock-3.12.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: typing-extensions in /Users/hraghu/opt/anaconda3/envs/stylemate/lib/python3.11/site-packages (from torch) (4.5.0)
# Collecting sympy (from torch)
#   Using cached sympy-1.11.1-py3-none-any.whl (6.5 MB)
# Collecting networkx (from torch)
#   Using cached networkx-3.1-py3-none-any.whl (2.1 MB)
# Collecting jinja2 (from torch)
#   Using cached Jinja2-3.1.2-py3-none-any.whl (133 kB)
# Collecting numpy (from torchvision)
#   Downloading numpy-1.24.3-cp311-cp311-macosx_10_9_x86_64.whl (19.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.8/19.8 MB 29.1 MB/s eta 0:00:0000:0100:01
# Collecting requests (from torchvision)
#   Downloading requests-2.29.0-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 2.6 MB/s eta 0:00:00
# Collecting pillow!=8.3.*,>=5.3.0 (from torchvision)
#   Downloading Pillow-9.5.0-cp311-cp311-macosx_10_10_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 26.1 MB/s eta 0:00:0000:0100:01
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Downloading MarkupSafe-2.1.2-cp311-cp311-macosx_10_9_x86_64.whl (13 kB)
# Collecting charset-normalizer<4,>=2 (from requests->torchvision)
#   Downloading charset_normalizer-3.1.0-cp311-cp311-macosx_10_9_x86_64.whl (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.7/123.7 kB 4.5 MB/s eta 0:00:00
# Collecting idna<4,>=2.5 (from requests->torchvision)
#   Using cached idna-3.4-py3-none-any.whl (61 kB)
# Collecting urllib3<1.27,>=1.21.1 (from requests->torchvision)
#   Using cached urllib3-1.26.15-py2.py3-none-any.whl (140 kB)
# Collecting certifi>=2017.4.17 (from requests->torchvision)
#   Using cached certifi-2022.12.7-py3-none-any.whl (155 kB)
# Collecting mpmath>=0.19 (from sympy->torch)
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: mpmath, urllib3, sympy, pillow, numpy, networkx, MarkupSafe, idna, filelock, charset-normalizer, certifi, requests, jinja2, torch, torchvision, torchaudio
# Successfully installed MarkupSafe-2.1.2 certifi-2022.12.7 charset-normalizer-3.1.0 filelock-3.12.0 idna-3.4 jinja2-3.1.2 mpmath-1.3.0 networkx-3.1 numpy-1.24.3 pillow-9.5.0 requests-2.29.0 sympy-1.11.1 torch-2.0.0 torchaudio-2.0.1 torchvision-0.15.1 urllib3-1.26.15

# %%
# !pip install img2vec_pytorch
# Out:
# Collecting img2vec_pytorch
#   Downloading img2vec_pytorch-1.0.1-py3-none-any.whl (6.9 kB)
# Requirement already satisfied: torch in /Users/hraghu/opt/anaconda3/envs/stylemate/lib/python3.11/site-packages (from img2vec_pytorch) (2.0.0)
# Requirement already satisfied: torchvision in /Users/hraghu/opt/anaconda3/envs/stylemate/lib/python3.11/site-packages (from img2vec_pytorch) (0.15.1)
# Requirement already satisfied: numpy in /Users/hraghu/opt/anaconda3/envs/stylemate/lib/python3.11/site-packages (from img2vec_pytorch) (1.24.3)
# Requirement already satisfied: filelock in /Users/hraghu/opt/anaconda3/envs/stylemate/lib/python3.11/site-packages (from torch->img2vec_pytorch) (3.12.0)
# Requirement already satisfied: typing-extensions in /Users/hraghu/opt/anaconda3/envs/stylemate/lib/python3.11/site-packages (from torch->img2vec_pytorch) (4.5.0)
# Requirement already satisfied: sympy in /Users/hraghu/opt/anaconda3/envs/stylemate/lib/python3.11/site-packages (from torch->img2vec_pytorch) (1.11.1)
# Requirement already satisfied: networkx in /Users/hraghu/opt/anaconda3/envs/stylemate/lib/python3.11/site-packages (from torch->img2vec_pytorch) (3.1)
# Requirement already satisfied: jinja2 in /Users/hraghu/opt/anaconda3/envs/stylemate/lib/python3.11/site-packages (from torch->img2vec_pytorch) (3.1.2)
# Requirement already satisfied: requests in /Users/hraghu/opt/anaconda3/envs/stylemate/lib/python3.11/site-packages (from torchvision->img2vec_pytorch) (2.29.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/hraghu/opt/anaconda3/envs/stylemate/lib/python3.11/site-packages (from torchvision->img2vec_pytorch) (9.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/hraghu/opt/anaconda3/envs/stylemate/lib/python3.11/site-packages (from jinja2->torch->img2vec_pytorch) (2.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/hraghu/opt/anaconda3/envs/stylemate/lib/python3.11/site-packages (from requests->torchvision->img2vec_pytorch) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/hraghu/opt/anaconda3/envs/stylemate/lib/python3.11/site-packages (from requests->torchvision->img2vec_pytorch) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/hraghu/opt/anaconda3/envs/stylemate/lib/python3.11/site-packages (from requests->torchvision->img2vec_pytorch) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/hraghu/opt/anaconda3/envs/stylemate/lib/python3.11/site-packages (from requests->torchvision->img2vec_pytorch) (2022.12.7)
# Requirement already satisfied: mpmath>=0.19 in /Users/hraghu/opt/anaconda3/envs/stylemate/lib/python3.11/site-packages (from sympy->torch->img2vec_pytorch) (1.3.0)
# Installing collected packages: img2vec_pytorch
# Successfully installed img2vec_pytorch-1.0.1

# %%
import torch

import numpy as np
import pandas as pd
import os

# %%
metadata = pd.read_csv('../Project_Data/Metadata.csv')
metadata.sample(2)
# Out:
#       Unnamed: 0                                           category tech1
# 1221        6362  ['Clothing, Shoes & Jewelry', 'Women', 'Clothi...   NaN  \
# 3500       43266  ['Clothing, Shoes & Jewelry', 'Women', 'Clothi...   NaN
#
#                                             description
# 1221  ['This beautiful, mid-weight kimono makes your...  \
# 3500  ['Keep your cool with Vanity Fair cooling touc...
#
#                                                     fit
# 1221   class="a-normal a-align-center a-spacing-smal...  \
# 3500   class="a-normal a-align-center a-spacing-smal...
#
#                                                   title
# 1221  Old Shanghai Women's Kimono Robe Long - Waterc...  \
# 3500  Vanity Fair Women's Cooling Touch Full Coverag...
#
#                                                also_buy
# 1221  ['B01H2G0AD6', 'B0106RGZVO', 'B07GV343HQ', 'B0...  \
# 3500  ['B0779GMG3Z', 'B004N3BHZ2', 'B07DLRV47L', 'B0...
#
#                                                   image  tech2         brand
# 1221  ['https://images-na.ssl-images-amazon.com/imag...    NaN  Old Shanghai  \
# 3500  ['https://images-na.ssl-images-amazon.com/imag...    NaN           NaN
#
#                                                 feature
# 1221  ['Polyester Charmeuse, 22mm. Machine wash cold...  \
# 3500  ['85% Nylon, 15% Spandex', 'Imported', 'Hook a...
#
#                                        rank
# 1221  23,929 in Clothing, Shoes & Jewelry (  \
# 3500  59,768 in Clothing, Shoes & Jewelry (
#
#                                               also_view details
# 1221  ['B008BVHWJM', 'B01H2G0AD6', 'B0106RGZVO', 'B0...      {}  \
# 3500  ['B004N3BHZ2', 'B0779GMG3Z', 'B076H6NT9J', 'B0...      {}
#
#                                                main_cat similar_item
# 1221  <img src="https://images-na.ssl-images-amazon....          NaN  \
# 3500  <img src="https://images-na.ssl-images-amazon....          NaN
#
#                                                    date            price
# 1221  <div class="a-fixed-left-grid a-spacing-none">...           $98.00  \
# 3500  <div class="a-fixed-left-grid a-spacing-none">...  $13.47 - $56.70
#
#             asin
# 1221  B00L4KHQ8Y
# 3500  B019JWNM18

# %%
from img2vec_pytorch import Img2Vec
from PIL import Image

# Initialize Img2Vec with GPU
img2vec = Img2Vec(cuda=False)

# Read in an image (rgb format)
img = Image.open('test.jpg')
# Get a vector from img2vec, returned as a torch FloatTensor
vec = img2vec.get_vec(img, tensor=True)
# Or submit a list
vectors = img2vec.get_vec(list_of_PIL_images)

# %%
import glob
print(glob.glob("../Project_Data/Image"))
